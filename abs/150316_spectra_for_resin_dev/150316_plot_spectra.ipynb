# %%
from __future__ import division
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BLSabsorption = np.loadtxt('BLS_in_ethyl_acetate.csv', delimiter=',')
UV326absorption = np.loadtxt('UV326absorptionspectrum.csv', delimiter=',')
Uvinul3026absorption = np.loadtxt('Uvinul 3026.csv', delimiter=',')
Tinuvin327absorption = np.loadtxt('Tinuvin 327.csv', delimiter=',')
Irgacure819absorption = np.loadtxt('Irgacure819absorptionspectrum.csv', delimiter=',')
TMDPOabsorption = np.loadtxt('TMDPOabsorptionspectrum.csv', delimiter=',')
LED385nm_Thorlabs = np.loadtxt('385nm_LED_Thorlabs_M385L2.csv', delimiter=',')

# %%
print('BLS array shape:',np.shape(BLSabsorption))
print('UV326 array shape:',np.shape(UV326absorption))
print('Uvinul 3026 array shape:',np.shape(Uvinul3026absorption))
print('Tinuvin 327 array shape:',np.shape(Tinuvin327absorption))
print('Irgacure array shape:',np.shape(Irgacure819absorption))
print('TMDPO array shape:',np.shape(TMDPOabsorption))
print('385 nm LED array shape:',np.shape(LED385nm_Thorlabs))
# Out:
# BLS array shape: (55, 2)
# UV326 array shape: (60, 2)
# Uvinul 3026 array shape: (60, 2)
# Tinuvin 327 array shape: (58, 2)
# Irgacure array shape: (63, 2)
# TMDPO array shape: (54, 2)
# 385 nm LED array shape: (66, 2)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.set_title('Current Resin',fontsize=18)
ax.plot(LED385nm_Thorlabs[:,0],LED385nm_Thorlabs[:,1], label='Thorlabs 385 nm LED')
ax.plot(BLSabsorption[:,0],BLSabsorption[:,1], label='BLS-99 UV absorber', color='k')
ax.plot(TMDPOabsorption[:,0],TMDPOabsorption[:,1], label='TMDPO photoinitiator', color='r')
ax.legend(bbox_to_anchor=(1, 0.95))
ax.set_xlabel('Wavelength (nm)',fontsize=12)
ax.set_ylabel('Absorption/Normalized Emission',fontsize=12)
ax.set_ylim(0,1.2)
plt.savefig('1-current resin', fmt='png')

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.set_title('Replace TMDPO With Irgacure 819',fontsize=18)
ax.plot(LED385nm_Thorlabs[:,0],LED385nm_Thorlabs[:,1], label='Thorlabs 385 nm LED')
ax.plot(BLSabsorption[:,0],BLSabsorption[:,1], label='BLS-99 UV absorber', color='k')
ax.plot(Irgacure819absorption[:,0],Irgacure819absorption[:,1], label='Irgacure 819', color='r')
ax.legend(bbox_to_anchor=(1, 0.95))
ax.set_xlabel('Wavelength (nm)',fontsize=12)
ax.set_ylabel('Absorption/Normalized Emission',fontsize=12)
ax.set_ylim(0,1.2)
plt.savefig('2-replace TMDPO with Irgacure819', fmt='png')

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.set_title('Replace BLS-99 With UV-326',fontsize=18)
ax.plot(LED385nm_Thorlabs[:,0],LED385nm_Thorlabs[:,1], label='Thorlabs 385 nm LED')
ax.plot(UV326absorption[:,0],UV326absorption[:,1], label='UV-326 UV absorber', color='k')
ax.plot(Irgacure819absorption[:,0],Irgacure819absorption[:,1], label='Irgacure 819', color='r')
ax.legend(bbox_to_anchor=(1, 0.95))
ax.set_xlabel('Wavelength (nm)',fontsize=12)
ax.set_ylabel('Absorption/Normalized Emission',fontsize=12)
ax.set_ylim(0,1.2)
plt.savefig('3-Replace BLS-99 with UV-326', fmt='png')

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(LED385nm_Thorlabs[:,0],LED385nm_Thorlabs[:,1], label='Thorlabs 385 nm LED')
ax.plot(BLSabsorption[:,0],BLSabsorption[:,1], label='BLS-99 UV absorber', color='k')
ax.plot(TMDPOabsorption[:,0],TMDPOabsorption[:,1], 'r', label='TMDPO')
ax.plot(UV326absorption[:,0],UV326absorption[:,1], 'k--', label='UV-326 UV absorber')
ax.plot(Irgacure819absorption[:,0],Irgacure819absorption[:,1], 'r--', label='Irgacure 819')
ax.legend(bbox_to_anchor=(1, 0.95))
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Absorption/Normalized Emission')
ax.set_ylim(0,1.2)
plt.savefig('4-all possibilities', fmt='png')

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(LED385nm_Thorlabs[:,0],LED385nm_Thorlabs[:,1], label='Thorlabs 385 nm LED')
ax.plot(BLSabsorption[:,0],BLSabsorption[:,1], label='BLS-99 UV absorber', color='k')
ax.plot(TMDPOabsorption[:,0],TMDPOabsorption[:,1], 'r', label='TMDPO')
ax.plot(UV326absorption[:,0],UV326absorption[:,1], 'k--', label='UV-326 UV absorber')
ax.plot(Irgacure819absorption[:,0],Irgacure819absorption[:,1], 'r--', label='Irgacure 819')
ax.plot(Uvinul3026absorption[:,0],Uvinul3026absorption[:,1], 'g--', label='Uvinul 3026 UV absorber')
ax.plot(Tinuvin327absorption[:,0],Tinuvin327absorption[:,1], 'm--', label='Tinuvin 327 UV absorber')
ax.legend(bbox_to_anchor=(1.2, 0.95))
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Absorption/Normalized Emission')
ax.set_ylim(0,1.2)
plt.savefig('6-all possibilities with uvinul 3026 and Tinuvin 327', fmt='png')
